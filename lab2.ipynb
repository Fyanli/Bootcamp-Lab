# %%
import pandas as pd
file1=pd.read_csv('file1.csv')

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file1.shape
# Out:
# (4008, 11)

# %%
file1.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
numerical1 = file1.select_dtypes(include=['float64','int64'])

# %%
numerical1
# Out:
#        Income  Monthly Premium Auto  Total Claim Amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 4003      NaN                   NaN                 NaN
# 4004      NaN                   NaN                 NaN
# 4005      NaN                   NaN                 NaN
# 4006      NaN                   NaN                 NaN
# 4007      NaN                   NaN                 NaN
#
# [4008 rows x 3 columns]

# %%
file1.isna().sum()
# Out:
# Customer                     2937
# ST                           2937
# GENDER                       3054
# Education                    2937
# Customer Lifetime Value      2940
# Income                       2937
# Monthly Premium Auto         2937
# Number of Open Complaints    2937
# Policy Type                  2937
# Vehicle Class                2937
# Total Claim Amount           2937
# dtype: int64

# %%
cols=[]
for column in file1.columns:
    cols.append(column.lower())
file1.columns=cols
file1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington      F                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN      F                     F
# 4004      NaN         NaN      F                     F
# 4005      NaN         NaN      F                     F
# 4006      NaN         NaN      F                     F
# 4007      NaN         NaN      F                     F
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file1.isnull()
# Out:
#       customer     st  gender  education  customer lifetime value  income  \
# 0        False  False   False      False                     True   False
# 1        False  False   False      False                    False   False
# 2        False  False   False      False                    False   False
# 3        False  False   False      False                    False   False
# 4        False  False   False      False                    False   False
# ...        ...    ...     ...        ...                      ...     ...
# 4003      True   True   False      False                     True    True
# 4004      True   True   False      False                     True    True
# 4005      True   True   False      False                     True    True
# 4006      True   True   False      False                     True    True
# 4007      True   True   False      False                     True    True
#
#       monthly premium auto  number of open complaints  policy type  \
# ...

# %%
file1['gender'].unique()
# Out:
# array(['F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
file1['gender'].value_counts()
# Out:
# F         3511
# M          413
# Male        39
# female      28
# Femal       17
# Name: gender, dtype: int64

# %%
file1['gender'].value_counts(dropna=False)
# Out:
# F         3511
# M          413
# Male        39
# female      28
# Femal       17
# Name: gender, dtype: int64

# %%
file1['gender']=file1['gender'].fillna('F')

# %%
file1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington      F                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN      F                     F
# 4004      NaN         NaN      F                     F
# 4005      NaN         NaN      F                     F
# 4006      NaN         NaN      F                     F
# 4007      NaN         NaN      F                     F
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file1=file1['education'].fillna('F')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0m/krm29zjx31j4v1ldykbq32vm0000gn/T/ipykernel_5717/3525109246.py in <module>
# ----> 1 file1=file1['education'].fillna('F')
#
# NameError: name 'file1' is not defined

# %%
file1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington      F                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN      F                     F
# 4004      NaN         NaN      F                     F
# 4005      NaN         NaN      F                     F
# 4006      NaN         NaN      F                     F
# 4007      NaN         NaN      F                     F
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
import datetime

# %%
file1['monthly premium auto']
# Out:
# 0       1000.0
# 1         94.0
# 2        108.0
# 3        106.0
# 4         68.0
#          ...
# 4003       NaN
# 4004       NaN
# 4005       NaN
# 4006       NaN
# 4007       NaN
# Name: monthly premium auto, Length: 4008, dtype: float64
